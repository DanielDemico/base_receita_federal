# %%
import os
import pandas as pd
import duckdb

# %%
estabelecimentos_paths = os.listdir('./files/estabelecimentos')
columns = ['cnpj_basico','cnpj_ordem','cnpj_dv','id_matriz/filial','nome_fantasia','situacao_cadastral','data_situacao_cadastral',
           'motivo_situacao_cadastral','cidade_exterior','pais','data_inicio_atividade','cnae_princ_cod','cnaes_secundarios','tipo_logradouro',
           'logradouro','numero','complemento','bairro','cep','uf','municipio','ddd1','telefone1','ddd2','telefone2','ddd_fax','fax','e-mail','situacao_especial',
            'dt_situacao_especial']

# %%
cnaes_princ = duckdb.sql(f"SELECT * FROM './files/estabelecimentos/{estabelecimentos_paths[0]}'")

# %%
df_estabelecimentos
# Out:
#          cnpj_basico  cnpj_ordem  cnpj_dv  id_matriz/filial  \
# 0            7396865           1       68                 1
# 1           64904295          18       51                 2
# 2           76016369           3       16                 2
# 3           52302726           1       82                 1
# 4            7396923           1       53                 1
# ...              ...         ...      ...               ...
# 4753430     39066921           1       92                 1
# 4753431     39067134           1       65                 1
# 4753432     37059778           1       86                 1
# 4753433     37060179           1       82                 1
# 4753434     28182127           1       98                 1
#
#                             nome_fantasia  situacao_cadastral  \
# 0                                     NaN                   8
# 1                                     NaN                   8
# 2                                     NaN                   4
# 3                                     NaN                   4
# 4                                     NaN                   8
# ...                                   ...                 ...
# 4753430                               NaN                   8
# 4753431                               NaN                   8
# 4753432                               NaN                   4
# 4753433  CLAUDIA DE CAMPOS REPRESENTACOES                   8
# 4753434           CAFFE ITALIA RISTORANTE                   4
#
#          data_situacao_cadastral  motivo_situacao_cadastral cidade_exterior  \
# 0                       20170210                          1             NaN
# 1                       20161110                          1             NaN
# 2                       20231113                         63             NaN
# 3                       20210406                         63             NaN
# 4                       20140115                          1             NaN
# ...                          ...                        ...             ...
# 4753430                 20210228                          1             NaN
# 4753431                 20210228                          1             NaN
# 4753432                 20221130                         63             NaN
# 4753433                 20230614                          1             NaN
# 4753434                 20210330                         63             NaN
#
#          pais  ...  municipio  ddd1   telefone1  ddd2   telefone2 ddd_fax  \
# 0         NaN  ...       8297  47.0    33851125  47.0  33851125.0    47.0
# 1         NaN  ...       2785  11.0    36491000  31.0  33880436.0    82.0
# 2         NaN  ...       7071   NaN         NaN   NaN         NaN     NaN
# 3         NaN  ...       6131   NaN         NaN   NaN         NaN     NaN
# 4         NaN  ...       7107  11.0    69658088   NaN         NaN     NaN
# ...       ...  ...        ...   ...         ...   ...         ...     ...
# 4753430   NaN  ...       7225   0.0         0.0   NaN         NaN     0.0
# 4753431   NaN  ...       3743   0.0         0.0   NaN         NaN     0.0
# 4753432   NaN  ...       6477  11.0  23585209.0   NaN         NaN     NaN
# 4753433   NaN  ...       6619  11.0  44764111.0   NaN         NaN     NaN
# 4753434   NaN  ...       4133  31.0  35321918.0   NaN         NaN     NaN
#
#               fax                             e-mail  situacao_especial  \
# 0        33851125                                NaN                NaN
# 1        33118379        CLAUDIO.GIGLIO@CAMIL.COM.BR                NaN
# 2             NaN                                NaN                NaN
# 3             NaN                                NaN                NaN
# 4             NaN                                NaN                NaN
# ...           ...                                ...                ...
# 4753430       0.0  carlosalbertosantana021@gmail.com                NaN
# 4753431       0.0               edna.ami@hotmail.com                NaN
# 4753432       NaN     MIRIAN_SOUZA_SILVA@HOTMAIL.COM                NaN
# 4753433       NaN  ERNESTOR.JUNIOR@ERJACCOUNT.COM.BR                NaN
# 4753434       NaN                ETICON@TERRA.COM.BR                NaN
#
#         dt_situacao_especial
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 4753430                  NaN
# 4753431                  NaN
# 4753432                  NaN
# 4753433                  NaN
# 4753434                  NaN
#
# [4753435 rows x 30 columns]
